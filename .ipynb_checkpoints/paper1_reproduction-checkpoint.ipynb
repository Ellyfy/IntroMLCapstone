# %%
# paper1_reproduction
"""
Reproduces the MDPI paper:
"Enhancing Sealing Performance Predictions: 
XGBoost vs Polynomial Regression with Advanced Optimization Techniques"
Focus: High-dimensional engineered features, XGBoost dominates polynomial regression.
"""
from xgboost_model import clf as xgb_model  
from poly_logistic_model import poly_lr_pipeline

print("Paper 1 Reproduction - MDPI")
# Evaluate XGBoost
print("XGBoost performance already printed in xgboost_model.ipynb")
# Evaluate Polynomial Logistic Regression
print("Polynomial Logistic Regression performance already printed in poly_logistic_model.ipynb")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       1 # paper1_reproduction
#       2 """
#       3 Reproduces the MDPI paper:
#       4 "Enhancing Sealing Performance Predictions:
#       5 XGBoost vs Polynomial Regression with Advanced Optimization Techniques"
#       6 Focus: High-dimensional engineered features, XGBoost dominates polynomial regression.
#       7 """
# ----> 8 from xgboost_model import clf as xgb_model  # reuse xgboost_model.py
#       9 from poly_logistic_model import poly_lr_pipeline
#      11 print("Paper 1 Reproduction - MDPI")
#
# ModuleNotFoundError: No module named 'xgboost_model'
