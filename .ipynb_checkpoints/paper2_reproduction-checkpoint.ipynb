# %%
# paper2_reproduction
"""
Reproduces the arXiv paper:
"Optimizing Fintech Marketing: Logistic Regression vs XGBoost"
Focus: Multi-class, sparse categorical dataset.
"""
from xgboost_model import clf as xgb_model
from poly_logistic_model import poly_lr_pipeline

print("Paper 2 Reproduction - arXiv")
# Evaluate XGBoost and Polynomial Logistic Regression on dataset
print("XGBoost and Polynomial Logistic Regression performance can be compared here")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 7
#       1 # paper2_reproduction
#       2 """
#       3 Reproduces the arXiv paper:
#       4 "Optimizing Fintech Marketing: Logistic Regression vs XGBoost"
#       5 Focus: Multi-class, sparse categorical dataset.
#       6 """
# ----> 7 from xgboost_model import clf as xgb_model
#       8 from poly_logistic_model import poly_lr_pipeline
#      10 print("Paper 2 Reproduction - arXiv")
#
# ModuleNotFoundError: No module named 'xgboost_model'
